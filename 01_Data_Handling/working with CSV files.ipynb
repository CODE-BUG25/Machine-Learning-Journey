# %% [markdown]
# # MACHINE LEARNING

# %%
import pandas as pd

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv')
# Out:
#           imdb_id                     title            original_title  year  \
# 0       tt0111161  The Shawshank Redemption  The Shawshank Redemption  1994
# 1       tt0468569           The Dark Knight           The Dark Knight  2008
# 2       tt1375666                 Inception                 Inception  2010
# 3       tt0137523                Fight Club                Fight Club  1999
# 4       tt0816692              Interstellar              Interstellar  2014
# ...           ...                       ...                       ...   ...
# 16247   tt3544218                   Belgica                   Belgica  2016
# 16248   tt0101733    Dil Hai Ki Manta Nahin    Dil Hai Ki Manta Nahin  1991
# 16249  tt10994688                 The Binge                 The Binge  2020
# 16250   tt0263743               Billionaire                 Milyarder  1987
# 16251   tt1921078          Saint Petersburg            San Peterzburg  2010
#
# ...

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv' ,header=1)
# Out:
#         tt0111161 The Shawshank Redemption The Shawshank Redemption.1  1994  \
# 0       tt0468569          The Dark Knight            The Dark Knight  2008
# 1       tt1375666                Inception                  Inception  2010
# 2       tt0137523               Fight Club                 Fight Club  1999
# 3       tt0816692             Interstellar               Interstellar  2014
# 4       tt0109830             Forrest Gump               Forrest Gump  1994
# ...           ...                      ...                        ...   ...
# 16246   tt3544218                  Belgica                    Belgica  2016
# 16247   tt0101733   Dil Hai Ki Manta Nahin     Dil Hai Ki Manta Nahin  1991
# 16248  tt10994688                The Binge                  The Binge  2020
# 16249   tt0263743              Billionaire                  Milyarder  1987
# 16250   tt1921078         Saint Petersburg             San Peterzburg  2010
#
#          142                    Drama  9.3  3182733  \
# ...

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv' ,index_col='imdb_id')
# Out:
#                                title            original_title  year  \
# imdb_id
# tt0111161   The Shawshank Redemption  The Shawshank Redemption  1994
# tt0468569            The Dark Knight           The Dark Knight  2008
# tt1375666                  Inception                 Inception  2010
# tt0137523                 Fight Club                Fight Club  1999
# tt0816692               Interstellar              Interstellar  2014
# ...                              ...                       ...   ...
# tt3544218                    Belgica                   Belgica  2016
# tt0101733     Dil Hai Ki Manta Nahin    Dil Hai Ki Manta Nahin  1991
# tt10994688                 The Binge                 The Binge  2020
# tt0263743                Billionaire                 Milyarder  1987
# tt1921078           Saint Petersburg            San Peterzburg  2010
#
#             runtime_minutes                   genres  average_rating  \
# imdb_id
# ...

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv' ,usecols=['title','genres','average_rating'])
# Out:
#                           title                   genres  average_rating
# 0      The Shawshank Redemption                    Drama             9.3
# 1               The Dark Knight       Action,Crime,Drama             9.1
# 2                     Inception  Action,Adventure,Sci-Fi             8.8
# 3                    Fight Club     Crime,Drama,Thriller             8.8
# 4                  Interstellar   Adventure,Drama,Sci-Fi             8.7
# ...                         ...                      ...             ...
# 16247                   Belgica                    Drama             6.7
# 16248    Dil Hai Ki Manta Nahin   Adventure,Comedy,Drama             7.2
# 16249                 The Binge                   Comedy             5.3
# 16250               Billionaire             Comedy,Drama             7.5
# 16251          Saint Petersburg       Comedy,Crime,Drama             6.4
#
# [16252 rows x 3 columns]

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv' ,skiprows=[1,3,4,5,6,7])
# Out:
#           imdb_id                                              title  \
# 0       tt0468569                                    The Dark Knight
# 1       tt0133093                                         The Matrix
# 2       tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 3       tt0167260      The Lord of the Rings: The Return of the King
# 4       tt0114369                                              Seven
# ...           ...                                                ...
# 16241   tt3544218                                            Belgica
# 16242   tt0101733                             Dil Hai Ki Manta Nahin
# 16243  tt10994688                                          The Binge
# 16244   tt0263743                                        Billionaire
# 16245   tt1921078                                   Saint Petersburg
#
#                                           original_title  year  \
# 0                                        The Dark Knight  2008
# ...

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv' ,nrows=10)
# Out:
#      imdb_id                                              title  \
# 0  tt0111161                           The Shawshank Redemption
# 1  tt0468569                                    The Dark Knight
# 2  tt1375666                                          Inception
# 3  tt0137523                                         Fight Club
# 4  tt0816692                                       Interstellar
# 5  tt0109830                                       Forrest Gump
# 6  tt0110912                                       Pulp Fiction
# 7  tt0133093                                         The Matrix
# 8  tt0120737  The Lord of the Rings: The Fellowship of the Ring
# 9  tt0167260      The Lord of the Rings: The Return of the King
#
#                                       original_title  year  runtime_minutes  \
# 0                           The Shawshank Redemption  1994              142
# 1                                    The Dark Knight  2008              152
# ...

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv' ,encoding='latin-1')
# Out:
#           imdb_id                     title            original_title  year  \
# 0       tt0111161  The Shawshank Redemption  The Shawshank Redemption  1994
# 1       tt0468569           The Dark Knight           The Dark Knight  2008
# 2       tt1375666                 Inception                 Inception  2010
# 3       tt0137523                Fight Club                Fight Club  1999
# 4       tt0816692              Interstellar              Interstellar  2014
# ...           ...                       ...                       ...   ...
# 16247   tt3544218                   Belgica                   Belgica  2016
# 16248   tt0101733    Dil Hai Ki Manta Nahin    Dil Hai Ki Manta Nahin  1991
# 16249  tt10994688                 The Binge                 The Binge  2020
# 16250   tt0263743               Billionaire                 Milyarder  1987
# 16251   tt1921078          Saint Petersburg            San Peterzburg  2010
#
# ...

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv' ,encoding='latin-1', ,on_bad_lines=False)
# Out:
#           imdb_id                     title            original_title  year  \
# 0       tt0111161  The Shawshank Redemption  The Shawshank Redemption  1994
# 1       tt0468569           The Dark Knight           The Dark Knight  2008
# 2       tt1375666                 Inception                 Inception  2010
# 3       tt0137523                Fight Club                Fight Club  1999
# 4       tt0816692              Interstellar              Interstellar  2014
# ...           ...                       ...                       ...   ...
# 16247   tt3544218                   Belgica                   Belgica  2016
# 16248   tt0101733    Dil Hai Ki Manta Nahin    Dil Hai Ki Manta Nahin  1991
# 16249  tt10994688                 The Binge                 The Binge  2020
# 16250   tt0263743               Billionaire                 Milyarder  1987
# 16251   tt1921078          Saint Petersburg            San Peterzburg  2010
#
# ...

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16252 entries, 0 to 16251
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   imdb_id          16252 non-null  object
#  1   title            16252 non-null  object
#  2   original_title   16252 non-null  object
#  3   year             16252 non-null  int64
#  4   runtime_minutes  16251 non-null  float64
#  5   genres           16246 non-null  object
#  6   average_rating   16252 non-null  float64
#  7   num_votes        16252 non-null  int64
#  8   imdb_url         16252 non-null  object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 1.1+ MB

# %%
pd.read_csv('imdb_top_movies_1980_2026.csv',dtype{'runtime_minutes':int})
# Out:
#   Cell In[58], line 1
#     pd.read_csv('imdb_top_movies_1980_2026.csv',dtype{'runtime_minutes':int})
#                                                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
dfs=pd.read_csv('imdb_top_movies_1980_2026.csv' ,chunksize=5000)

# %%
for chunks in dfs:
    print(chunks.shape)
# Out:
# (5000, 9)
# (5000, 9)
# (5000, 9)
# (1252, 9)

# %%
1.# working with json
# Out:
# 1.0

# %%
pd.read_json('test.json')
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]
