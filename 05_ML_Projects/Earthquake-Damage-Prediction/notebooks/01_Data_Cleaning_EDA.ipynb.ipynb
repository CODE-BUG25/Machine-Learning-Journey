# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from scipy import stats

# Plot settings
plt.style.use("ggplot")
sns.set_palette("viridis")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# %%
df = pd.read_csv("earthquake_1995-2023.csv")

df.head()
# Out:
#                                       title  magnitude         date_time  cdi  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47    7
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22    8
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05    7
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48    6
# 4                  M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48    0
#
#    mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
#    latitude  longitude               location      continent    country
# 0  -13.8814   167.1580          Sola, Vanuatu            NaN    Vanuatu
# 1   12.8140   -88.1265  Intipucá, El Salvador            NaN        NaN
# 2  -38.1911   -70.3731    Loncopué, Argentina  South America  Argentina
# 3   54.3844  -160.6990     Sand Point, Alaska            NaN        NaN
# 4   54.4900  -160.7960       Alaska Peninsula            NaN        NaN

# %%
print("Rows :", df.shape[0])
print("Columns :", df.shape[1])
# Out:
# Rows : 1000
# Columns : 19

# %%
df.columns
# Out:
# Index(['title', 'magnitude', 'date_time', 'cdi', 'mmi', 'alert', 'tsunami',
#        'sig', 'net', 'nst', 'dmin', 'gap', 'magType', 'depth', 'latitude',
#        'longitude', 'location', 'continent', 'country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      1000 non-null   object
#  1   magnitude  1000 non-null   float64
#  2   date_time  1000 non-null   object
#  3   cdi        1000 non-null   int64
#  4   mmi        1000 non-null   int64
#  5   alert      449 non-null    object
#  6   tsunami    1000 non-null   int64
#  7   sig        1000 non-null   int64
#  8   net        1000 non-null   object
#  9   nst        1000 non-null   int64
#  10  dmin       1000 non-null   float64
#  11  gap        1000 non-null   float64
#  12  magType    1000 non-null   object
#  13  depth      1000 non-null   float64
#  14  latitude   1000 non-null   float64
#  15  longitude  1000 non-null   float64
#  16  location   994 non-null    object
#  17  continent  284 non-null    object
#  18  country    651 non-null    object
# dtypes: float64(6), int64(5), object(8)
# memory usage: 148.6+ KB

# %%
df.describe(include='all').T
# Out:
#             count unique                                    top freq  \
# title        1000    984  M 6.5 - Kermadec Islands, New Zealand    3
# magnitude  1000.0    NaN                                    NaN  NaN
# date_time    1000    990                       11-01-2022 12:39    3
# cdi        1000.0    NaN                                    NaN  NaN
# mmi        1000.0    NaN                                    NaN  NaN
# alert         449      4                                  green  353
# tsunami    1000.0    NaN                                    NaN  NaN
# sig        1000.0    NaN                                    NaN  NaN
# net          1000     11                                     us  960
# nst        1000.0    NaN                                    NaN  NaN
# dmin       1000.0    NaN                                    NaN  NaN
# gap        1000.0    NaN                                    NaN  NaN
# magType      1000      9                                    mww  502
# depth      1000.0    NaN                                    NaN  NaN
# latitude   1000.0    NaN                                    NaN  NaN
# longitude  1000.0    NaN                                    NaN  NaN
# location      994    502               Kokopo, Papua New Guinea   29
# continent     284      6                                   Asia  137
# country       651     56                              Indonesia  140
#
#                 mean         std      min       25%      50%        75%  \
# title            NaN         NaN      NaN       NaN      NaN        NaN
# magnitude    6.94015    0.438148      6.5       6.6      6.8        7.1
# date_time        NaN         NaN      NaN       NaN      NaN        NaN
# cdi            3.605    3.328972      0.0       0.0      4.0        7.0
# mmi            6.027     1.43399      1.0       5.0      6.0        7.0
# alert            NaN         NaN      NaN       NaN      NaN        NaN
# tsunami        0.325    0.468609      0.0       0.0      0.0        1.0
# sig          847.915  301.802632    650.0     691.0    744.0     874.25
# net              NaN         NaN      NaN       NaN      NaN        NaN
# nst          193.918  239.045858      0.0       0.0      0.0      403.0
# dmin        1.125174    2.073164      0.0       0.0      0.0    1.54925
# gap         20.92629   24.415895      0.0       0.0     18.0       27.0
# magType          NaN         NaN      NaN       NaN      NaN        NaN
# depth      74.612541   130.81259      2.7      16.0     29.0       55.0
# latitude    4.315554    26.63332 -61.8484  -13.5185  -2.4435   25.16725
# longitude  51.486576  117.478302 -179.968 -71.69445  107.791  148.36475
# location         NaN         NaN      NaN       NaN      NaN        NaN
# continent        NaN         NaN      NaN       NaN      NaN        NaN
# country          NaN         NaN      NaN       NaN      NaN        NaN
#
#                max
# title          NaN
# magnitude      9.1
# date_time      NaN
# cdi            9.0
# mmi           10.0
# alert          NaN
# tsunami        1.0
# sig         2910.0
# net            NaN
# nst          934.0
# dmin        17.654
# gap          239.0
# magType        NaN
# depth       670.81
# latitude   71.6312
# longitude  179.662
# location       NaN
# continent      NaN
# country        NaN

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# continent    716
# alert        551
# country      349
# location       6
# dmin           0
# longitude      0
# latitude       0
# depth          0
# magType        0
# gap            0
# title          0
# magnitude      0
# net            0
# sig            0
# tsunami        0
# mmi            0
# cdi            0
# date_time      0
# nst            0
# dtype: int64

# %%
missing = pd.DataFrame({
    "Missing Values":df.isnull().sum(),
    "Percentage":round(df.isnull().mean()*100,2)
})

missing.sort_values("Percentage",ascending=False)
# Out:
#            Missing Values  Percentage
# continent             716        71.6
# alert                 551        55.1
# country               349        34.9
# location                6         0.6
# dmin                    0         0.0
# longitude               0         0.0
# latitude                0         0.0
# depth                   0         0.0
# magType                 0         0.0
# gap                     0         0.0
# title                   0         0.0
# magnitude               0         0.0
# net                     0         0.0
# sig                     0         0.0
# tsunami                 0         0.0
# mmi                     0         0.0
# cdi                     0         0.0
# date_time               0         0.0
# nst                     0         0.0

# %%
print("Duplicate Rows :",df.duplicated().sum())
# Out:
# Duplicate Rows : 0

# %%
df.drop_duplicates(inplace=True)

print(df.shape)
# Out:
# (1000, 19)

# %%
df.dtypes
# Out:
# title         object
# magnitude    float64
# date_time     object
# cdi            int64
# mmi            int64
# alert         object
# tsunami        int64
# sig            int64
# net           object
# nst            int64
# dmin         float64
# gap          float64
# magType       object
# depth        float64
# latitude     float64
# longitude    float64
# location      object
# continent     object
# country       object
# dtype: object

# %%
df['date_time']=pd.to_datetime(df['date_time'])

# %%
df["Year"]=df["date_time"].dt.year
df["Month"]=df["date_time"].dt.month
df["Day"]=df["date_time"].dt.day
df["Hour"]=df["date_time"].dt.hour

df.head()
# Out:
#                                       title  magnitude           date_time  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5 2023-08-16 12:47:00
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5 2023-07-19 00:22:00
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6 2023-07-17 03:05:00
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2 2023-07-16 06:48:00
# 4                  M 7.3 - Alaska Peninsula        7.3 2023-07-16 06:48:00
#
#    cdi  mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    7    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    8    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    7    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    0    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
#    latitude  longitude               location      continent    country  Year  \
# 0  -13.8814   167.1580          Sola, Vanuatu            NaN    Vanuatu  2023
# 1   12.8140   -88.1265  Intipucá, El Salvador            NaN        NaN  2023
# 2  -38.1911   -70.3731    Loncopué, Argentina  South America  Argentina  2023
# 3   54.3844  -160.6990     Sand Point, Alaska            NaN        NaN  2023
# 4   54.4900  -160.7960       Alaska Peninsula            NaN        NaN  2023
#
#    Month  Day  Hour
# 0      8   16    12
# 1      7   19     0
# 2      7   17     3
# 3      7   16     6
# 4      7   16     6

# %%
numerical=df.select_dtypes(include=np.number)

numerical.columns
# Out:
# Index(['magnitude', 'cdi', 'mmi', 'tsunami', 'sig', 'nst', 'dmin', 'gap',
#        'depth', 'latitude', 'longitude', 'Year', 'Month', 'Day', 'Hour'],
#       dtype='object')

# %%
categorical=df.select_dtypes(include="object")

categorical.columns
# Out:
# Index(['title', 'alert', 'net', 'magType', 'location', 'continent', 'country'], dtype='object')

# %%
df.hist(figsize=(18,15),bins=30)

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["magnitude"],kde=True)

plt.title("Magnitude Distribution")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.histplot(df["depth"],bins=30,kde=True)

plt.show()

# %%
plt.figure(figsize=(6,4))

sns.countplot(x="tsunami",data=df)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(x="alert",data=df)

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x=df["magnitude"])

plt.show()

# %%
plt.figure(figsize=(8,4))

sns.boxplot(x=df["depth"])

plt.show()

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    x="depth",
    y="magnitude",
    data=df
)

plt.show()

# %%
plt.figure(figsize=(7,5))

sns.boxplot(
    x="tsunami",
    y="magnitude",
    data=df
)

plt.show()

# %%
plt.figure(figsize=(14,6))

df["country"].value_counts().head(15).plot(kind="bar")

plt.title("Top Countries")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    y="continent",
    data=df,
    order=df["continent"].value_counts().index
)

plt.show()

# %%
plt.figure(figsize=(15,5))

df["Year"].value_counts().sort_index().plot()

plt.xlabel("Year")

plt.ylabel("Number of Earthquakes")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.countplot(x="Month",data=df)

plt.show()

# %%
plt.figure(figsize=(14,10))

corr=df.select_dtypes(include=np.number).corr()

sns.heatmap(corr,
            annot=True,
            cmap="coolwarm",
            fmt=".2f")

plt.show()

# %%
sns.pairplot(
    df[["magnitude","depth","sig","mmi","cdi"]]
)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.kdeplot(df["magnitude"],fill=True)

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.violinplot(y=df["depth"])

plt.show()

# %%
Q1=df["magnitude"].quantile(0.25)

Q3=df["magnitude"].quantile(0.75)

IQR=Q3-Q1

lower=Q1-1.5*IQR

upper=Q3+1.5*IQR

outliers=df[(df["magnitude"]<lower) | (df["magnitude"]>upper)]

print("Outliers :",len(outliers))
# Out:
# Outliers : 47

# %%
corr=df.corr(numeric_only=True)

corr["magnitude"].sort_values(ascending=False)
# Out:
# magnitude    1.000000
# sig          0.512358
# mmi          0.282275
# cdi          0.163170
# nst          0.091427
# Hour         0.022847
# Day          0.019070
# depth        0.017083
# tsunami     -0.001213
# Month       -0.002377
# longitude   -0.010710
# latitude    -0.017505
# Year        -0.036082
# dmin        -0.081518
# gap         -0.087029
# Name: magnitude, dtype: float64

# %%
print(df["magnitude"].describe())

print(df["magnitude"].min())

print(df["magnitude"].max())

print(df["magnitude"].head(20))
# Out:
# count    1000.000000
# mean        6.940150
# std         0.438148
# min         6.500000
# 25%         6.600000
# 50%         6.800000
# 75%         7.100000
# max         9.100000
# Name: magnitude, dtype: float64
# 6.5
# 9.1
# 0     6.5
# 1     6.5
# 2     6.6
# 3     7.2
# 4     7.3
# 5     6.6
# 6     6.9
# 7     7.2
# 8     6.6
# 9     7.1
# 10    7.7
# 11    7.6
# 12    6.6
# 13    7.1
# 14    7.1
# 15    6.7
# 16    7.0
# 17    6.5
# 18    7.0
# 19    6.5
# Name: magnitude, dtype: float64

# %%
df["Risk_Score"]=(
    df["magnitude"]*0.5+
    df["mmi"]*0.2+
    df["cdi"]*0.2+
    df["sig"]/1000
)

# %%
# Create Damage_Level using Risk Score

q1 = df["Risk_Score"].quantile(0.25)
q2 = df["Risk_Score"].quantile(0.50)
q3 = df["Risk_Score"].quantile(0.75)

df["Damage_Level"] = pd.cut(
    df["Risk_Score"],
    bins=[-float("inf"), q1, q2, q3, float("inf")],
    labels=["Low", "Moderate", "High", "Severe"]
)

print(df["Damage_Level"].value_counts())
# Out:
# Damage_Level
# Low         258
# Severe      250
# High        248
# Moderate    244
# Name: count, dtype: int64

# %%
X = df.drop(columns=["Damage_Level", "Risk_Score"])

y = df["Damage_Level"]

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x="Damage_Level",
    data=df,
    order=["Low","Moderate","High","Severe"]
)

plt.show()

# %%
df.to_csv("earthquake_cleaned.csv",index=False)

print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully

# %%
df.shape
# Out:
# (1000, 25)

# %%
df.head()
# Out:
#                                       title  magnitude           date_time  \
# 0          M 6.5 - 42 km W of Sola, Vanuatu        6.5 2023-08-16 12:47:00
# 1  M 6.5 - 43 km S of Intipucá, El Salvador        6.5 2023-07-19 00:22:00
# 2  M 6.6 - 25 km ESE of Loncopué, Argentina        6.6 2023-07-17 03:05:00
# 3     M 7.2 - 98 km S of Sand Point, Alaska        7.2 2023-07-16 06:48:00
# 4                  M 7.3 - Alaska Peninsula        7.3 2023-07-16 06:48:00
#
#    cdi  mmi   alert  tsunami  sig net  nst      dmin    gap magType    depth  \
# 0    7    4   green        0  657  us  114  7.177000   25.0     mww  192.955
# 1    8    6  yellow        0  775  us   92  0.679000   40.0     mww   69.727
# 2    7    5   green        0  899  us   70  1.634000   28.0     mww  171.371
# 3    6    6   green        1  860  us  173  0.907000   36.0     mww   32.571
# 4    0    5     NaN        1  820  at   79  0.879451  172.8      Mi   21.000
#
#    latitude  longitude               location      continent    country  Year  \
# 0  -13.8814   167.1580          Sola, Vanuatu            NaN    Vanuatu  2023
# 1   12.8140   -88.1265  Intipucá, El Salvador            NaN        NaN  2023
# 2  -38.1911   -70.3731    Loncopué, Argentina  South America  Argentina  2023
# 3   54.3844  -160.6990     Sand Point, Alaska            NaN        NaN  2023
# 4   54.4900  -160.7960       Alaska Peninsula            NaN        NaN  2023
#
#    Month  Day  Hour Damage_Level  Risk_Score
# 0      8   16    12         High       6.107
# 1      7   19     0         High       6.825
# 2      7   17     3         High       6.599
# 3      7   16     6       Severe       6.860
# 4      7   16     6     Moderate       5.470

# %%
print("""
Exploratory Data Analysis Completed Successfully

✔ Missing Values Checked
✔ Duplicate Rows Removed
✔ Date Features Created
✔ Outliers Detected
✔ 15+ Visualizations Created
✔ Damage_Level Target Generated

Dataset Ready for Feature Engineering.
""")
# Out:
# Exploratory Data Analysis Completed Successfully
#
# ✔ Missing Values Checked
# ✔ Duplicate Rows Removed
# ✔ Date Features Created
# ✔ Outliers Detected
# ✔ 15+ Visualizations Created
# ✔ Damage_Level Target Generated
#
# Dataset Ready for Feature Engineering.
