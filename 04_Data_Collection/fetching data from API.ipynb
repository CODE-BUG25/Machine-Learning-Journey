# %%
import pandas as pd
import requests

# %%
response=requests.get('https://newsapi.org/v2/everything?q=tesla&from=2026-05-29&sortBy=publishedAt&apiKey=6061fb2e055f471b91ffe52f5063b488')

# %%
response.json()['articles']
# Out:
# [{'source': {'id': None, 'name': 'Pypi.org'},
#   'author': None,
#   'title': 'pyeasyequities added to PyPI',
#   'description': 'Unofficial Easy Equities and Satrix Python Client',
#   'url': 'https://pypi.org/project/pyeasyequities/',
#   'urlToImage': 'https://pypi.org/static/images/twitter.abaf4b19.webp',
#   'publishedAt': '2026-06-28T05:55:29Z',
#   'content': 'Unofficial Python client for Easy Equities and Satrix. Intended for personal use.\r\nSupports Python 3.8+.\r\nPyPI\r\nInstallation\r\npip install pyeasyequities\r\nFeatures\r\nAccounts\r\n<ul><li>List accounts: cl… [+4867 chars]'},
#  {'source': {'id': None, 'name': 'Github.com'},
#   'author': 'darndt',
#   'title': 'ripienaar/free-for-dev: A list of SaaS, PaaS and IaaS offerings that have free tiers of interest to devops and infradev',
#   'description': 'A list of SaaS, PaaS and IaaS offerings that have free tiers of interest to devops and infradev - ripienaar/free-for-dev',
# ...

# %%
df = pd.DataFrame(response.json()['articles'])

# %%
pd.DataFrame(response.json()['articles']).head(10)
# Out:
#                                          source            author  \
# 0              {'id': None, 'name': 'Pypi.org'}              None
# 1            {'id': None, 'name': 'Github.com'}            darndt
# 2  {'id': 'hacker-news', 'name': 'Hacker News'}           cwilkes
# 3            {'id': None, 'name': 'Biztoc.com'}  notateslaapp.com
# 4     {'id': None, 'name': 'Korrespondent.net'}                 1
# 5            {'id': None, 'name': 'Novinky.cz'}    Monika Kuncová
# 6              {'id': None, 'name': 'Ixbt.com'}               Jin
# 7             {'id': None, 'name': '3dnews.ru'}              None
# 8            {'id': None, 'name': 'Biztoc.com'}       electrek.co
# 9            {'id': None, 'name': 'Onliner.by'}           Onliner
#
#                                                title  \
# 0                       pyeasyequities added to PyPI
# 1  ripienaar/free-for-dev: A list of SaaS, PaaS a...
# 2      The Doorman's Fallacy in action | Hacker News
# ...

# %%
pd.DataFrame(response.json()['articles'])[['author','title','description','publishedAt']]
# Out:
#               author                                              title  \
# 0               None                       pyeasyequities added to PyPI
# 1             darndt  ripienaar/free-for-dev: A list of SaaS, PaaS a...
# 2            cwilkes      The Doorman's Fallacy in action | Hacker News
# 3   notateslaapp.com  Tesla Releases Q2 2026 Analyst Delivery Consensus
# 4                  1                   Війна на Близькому Сході. Онлайн
# ..               ...                                                ...
# 93     Eber do Carmo  Novo Hyundai Elantra cresce e muda de cara par...
# 94              None  2028 hopeful fires back at Elon Musk after tri...
# 95       Shawn Tully  Big Short legend Steve Eisman says everyone is...
# 96     Levent Öztürk  Tesla için rüzgar tersine döndü, Avrupa satışl...
# 97    Alberto Martín  Nos colaron un detalle nostálgico en Los Cuatr...
#
#                                           description           publishedAt
# ...

# %%
df.shape
# Out:
# (98, 8)

# %%
df.to_csv('news.csv')
